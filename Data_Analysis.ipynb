# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

csv1 = pd.read_csv("C:\\Users\\souna\\Downloads\\Registration for Quiz Competition for B.Tech 1st year 2022, DSCSITSC (Responses).csv")
csv1
# Out:
#     Sl.No.  Unnamed: 1 Name of the Head of the Group:  Unnamed: 3  \
# 0        1         NaN                      Sagar Sen         NaN
# 1        2         NaN                 Soumyadeep Das         NaN
# 2        3         NaN           SOUBHAGYA MUKHERJEE          NaN
# 3        4         NaN                      Rohan Roy         NaN
# 4        5         NaN                  Subham Maity          NaN
# 5        6         NaN              PARAMBRATA GHOSH          NaN
# 6        7         NaN           Snehasish Mukherjee          NaN
# 7        8         NaN                 Sanjana Biswas         NaN
# 8        9         NaN                      Arya Bose         NaN
# 9       10         NaN                  Aritra Haldar         NaN
# 10      11         NaN           Angshuman pramanick          NaN
# 11      12         NaN                 Sounak Sarkar          NaN
# 12      13         NaN                   AVIJIT MANNA         NaN
# ...

# %%
csv1.head()
# Out:
#    Sl.No.  Unnamed: 1 Name of the Head of the Group:  Unnamed: 3  \
# 0       1         NaN                      Sagar Sen         NaN
# 1       2         NaN                 Soumyadeep Das         NaN
# 2       3         NaN           SOUBHAGYA MUKHERJEE          NaN
# 3       4         NaN                      Rohan Roy         NaN
# 4       5         NaN                  Subham Maity          NaN
#
#   Write down the name of all participants of the group with mentioning Section & Stream [Ex.- Name- Sec-A-CSE]  \
# 0  Priyangsu Banik - Sec-B-CSE\nSanjida Biswas - ...
# 1  Soumyadip Das-Sec C-CSE\nSoumyajeet Saha-Sec C...
# 2  SOUBHAGYA MUKHERJEE-(SEC-C)-CSE\nShramana Show...
# 3  Bitan De, Rohan Roy, Alamin Molla, Sayan Pradh...
# 4  Surajit Pakira (CSE SEC-C)\nSayandeep Bera (CS...
#
#    Unnamed: 5 Name of Mentor for Head of the Grp: Section  Team No.
# 0         NaN                        Pallabi Bose       B         1
# ...

# %%
csv1.describe()
# Out:
#           Sl.No.  Unnamed: 1  Unnamed: 3  Unnamed: 5   Team No.
# count  24.000000         0.0         0.0         0.0  24.000000
# mean   12.500000         NaN         NaN         NaN  12.500000
# std     7.071068         NaN         NaN         NaN   7.071068
# min     1.000000         NaN         NaN         NaN   1.000000
# 25%     6.750000         NaN         NaN         NaN   6.750000
# 50%    12.500000         NaN         NaN         NaN  12.500000
# 75%    18.250000         NaN         NaN         NaN  18.250000
# max    24.000000         NaN         NaN         NaN  24.000000

# %%
plt.plot(csv1['Section'])
plt.savefig("plot4.png",dpi=2000)

# %%
csv1.loc[[0,1,2,3,4,5,6],["Section"]]
# Out:
#   Section
# 0       B
# 1       C
# 2       C
# 3       E
# 4       C
# 5       B
# 6       E

# %%
csv1.plot("Section",color='red')
plt.grid()
plt.savefig("plot5.png",dpi=2000)

# %%
var=np.array(csv1['Section'])
plt.hist(var,bins=10,edgecolor='black',cumulative=-1)
plt.savefig("plot3.png",dpi=2000)

# %%
plt.stem(csv1["Section"],label="SECTION",orientation="horizontal")
plt.legend()
plt.title("Section Distribution")
plt.savefig("plot2.png",dpi=2000)

# %%
pd.DataFrame(csv1["Name of the Head of the Group:"])
# Out:
#    Name of the Head of the Group:
# 0                       Sagar Sen
# 1                  Soumyadeep Das
# 2            SOUBHAGYA MUKHERJEE
# 3                       Rohan Roy
# 4                   Subham Maity
# 5               PARAMBRATA GHOSH
# 6            Snehasish Mukherjee
# 7                  Sanjana Biswas
# 8                       Arya Bose
# 9                   Aritra Haldar
# 10           Angshuman pramanick
# 11                 Sounak Sarkar
# 12                   AVIJIT MANNA
# 13                    Abir Mondal
# 14                Prithwis Ghorui
# 15                 shoubhik ghosh
# 16           Sufiya Ahmed Ansari
# 17                   SAGNIK NANDI
# 18                   Joydeep Dey
# 19              Swarnava Samanta
# 20                   Teesha singh
# 21               Sourik Majumder
# 22            Debayan Chakraborty
# 23               Kishan Derasree

# %%
pd.DataFrame(csv1['Name of Mentor for Head of the Grp:'])
# Out:
#    Name of Mentor for Head of the Grp:
# 0                         Pallabi Bose
# 1              Debasmita Roychowdhury
# 2               Debasmita Roychowdhury
# 3                     Dr. Dipankar das
# 4              Debosmita Roy Chowdhury
# 5                         Pallabi Bose
# 6                      Dr Dipankar Das
# 7                   Madam Pallabi Bose
# 8                           Vivek shaw
# 9                        Akash Mallik
# 10                         Vivek shaw
# 11                    Nibedita Biswas
# 12                 Ms. Nibedita Biswas
# 13                          Vivek shaw
# 14                     Prithwis Ghorui
# 15             debasmita roy chowdhury
# 16                        Pallabi Bose
# 17                     NIBEDITA BISWAS
# 18                    Nibedita Biswas
# 19             Debasmita Roy Chowdhury
# 20                     DR.DIPANKAR DAS
# 21                    Sourik Majumder
# 22                         Vivek shaw
# ...

# %%
csv1.loc[[0],["Name of the Head of the Group:"]]="JOSHITA BHATTACHRAYA"
pd.DataFrame(csv1["Name of the Head of the Group:"])
plt.plot(csv1["Name of the Head of the Group:"],color='red')
plt.savefig("plot1.png",dpi=2000)
